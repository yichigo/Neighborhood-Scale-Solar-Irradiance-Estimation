# %%
import pandas as pd
import numpy as np
import netCDF4
from netCDF4 import Dataset
import matplotlib.pyplot as plt
import os

# %%
dir_ozone = '../data/Ozone/'
dir_figure = '../figures/ozone/'

filename_prev = 'OMI-Aura_L3-OMDOAO3e_'
filenames = [filename for filename in os.listdir(dir_ozone) if filename_prev in filename]
filenames = sorted(filenames)

# %%
for filename in filenames:
    date = filename[21:30]
    year = date[:4]
    month = date[-4:-2]
    day = date[-2:]
    print(year, month, day)
    
    try:
        f = Dataset(dir_ozone + filename)

        lons = f.variables['lon'][:].data
        lons[lons > 180] -= 360
        lats = f.variables['lat'][:].data
        lons, lats = np.meshgrid(lons, lats)
        values = f.variables['ColumnAmountO3'][:].data
        unit = f.variables['ColumnAmountO3'].Units

        iwant = (values > 0)

        plt.rcParams["figure.figsize"] = (12, 6) # (w, h)
        plt.rcParams.update({'font.size': 20})

        plt.scatter(lons[iwant], lats[iwant], c = values[iwant], vmin=150, vmax=550, cmap = 'jet', s = 1)
        plt.colorbar()
        plt.title('Column Amount $O_3$ / ' + unit + ': ' + year +'-'+ month + '-' + day)
        plt.xlabel('longitude')
        plt.ylabel('latitude')
        plt.xticks(ticks = np.array(range(-180,181,60)), labels = np.array(range(-180,181,60)))
        plt.yticks(ticks = np.array(range(-90,90,30)), labels = np.array(range(-90,90,30)))
        plt.savefig(dir_figure + year +'_'+ month + '_' + day + '.png')
        plt.close()
    except:
        print('Error on reading file of ', year, month, day)
#     break
# Out:
# 2019 12 01
# 2019 12 02
# 2019 12 03
# 2019 12 04
# 2019 12 05
# 2019 12 06
# 2019 12 07
# 2019 12 08
# 2019 12 09
# 2019 12 10
# 2019 12 11
# 2019 12 12
# 2019 12 13
# 2019 12 14
# 2019 12 15
# 2019 12 16
# 2019 12 17
# 2019 12 18
# 2019 12 19
# 2019 12 20
# 2019 12 21
# 2019 12 22
# 2019 12 23
# 2019 12 24
# 2019 12 25
# 2019 12 26
# 2019 12 27
# 2019 12 28
# 2019 12 29
# 2019 12 30
# 2019 12 31
# 2020 01 01
# 2020 01 02
# 2020 01 03
# 2020 01 04
# 2020 01 05
# 2020 01 06
# 2020 01 07
# 2020 01 08
# 2020 01 09
# 2020 01 10
# 2020 01 11
# 2020 01 12
# 2020 01 13
# 2020 01 14
# 2020 01 15
# 2020 01 16
# 2020 01 17
# 2020 01 18
# 2020 01 19
# 2020 01 20
# 2020 01 21
# 2020 01 22
# 2020 01 23
# 2020 01 24
# 2020 01 25
# 2020 01 26
# 2020 01 27
# 2020 01 28
# 2020 01 29
# 2020 01 30
# 2020 01 31
# 2020 02 01
# 2020 02 02
# 2020 02 03
# 2020 02 04
# 2020 02 05
# Error on reading file of  2020 02 05
# 2020 02 06
# 2020 02 07
# 2020 02 08
# 2020 02 09
# 2020 02 10
# 2020 02 11
# 2020 02 12
# 2020 02 13
# 2020 02 14
# 2020 02 15
# 2020 02 16
# 2020 02 17
# 2020 02 18
# 2020 02 19
# 2020 02 20
# 2020 02 21
# 2020 02 22
# 2020 02 23
# 2020 02 24
# 2020 02 25
# 2020 02 26
# 2020 02 27
# 2020 02 28
# 2020 02 29
# 2020 03 01
# 2020 03 02
# 2020 03 03
# 2020 03 04
# 2020 03 05
# 2020 03 06
# 2020 03 07
# 2020 03 08
# 2020 03 09
# 2020 03 10
# 2020 03 11
# 2020 03 12
# 2020 03 13
# 2020 03 14
# 2020 03 15
# 2020 03 16
# 2020 03 17
# 2020 03 18
# 2020 03 19
# 2020 03 20
# 2020 03 21
# 2020 03 22
# 2020 03 23
# 2020 03 24
# 2020 03 25
# 2020 03 26
# 2020 03 27
# 2020 03 28
# 2020 03 29
# 2020 03 30
# 2020 03 31
# 2020 04 01
# 2020 04 02
# 2020 04 03
# 2020 04 04
# 2020 04 05
# 2020 04 06
# 2020 04 07
# 2020 04 08
# 2020 04 09
# 2020 04 10
# 2020 04 11
# 2020 04 12
# 2020 04 13
# 2020 04 14
# 2020 04 15
# 2020 04 16
# 2020 04 17
# 2020 04 18
# 2020 04 19
# 2020 04 20
# 2020 04 21
# 2020 04 22
# 2020 04 23
# 2020 04 24
# 2020 04 25
# 2020 04 26
# 2020 04 27
# 2020 04 28
# 2020 04 29
# 2020 04 30
# 2020 05 01
# 2020 05 02
# 2020 05 03
# 2020 05 04
# 2020 05 05
# 2020 05 06
# 2020 05 07
# 2020 05 08
# 2020 05 09
# 2020 05 10
# 2020 05 11
# 2020 05 12
# 2020 05 13
# 2020 05 14
# 2020 05 15
# 2020 05 16
# 2020 05 17
# 2020 05 18
# 2020 05 19
# 2020 05 20
# 2020 05 21
# 2020 05 22
# 2020 05 23
# 2020 05 24
# 2020 05 25
# 2020 05 26
# 2020 05 27
# 2020 05 28
# 2020 05 29
# 2020 05 30
# 2020 05 31
# 2020 06 01

# %%
plt.scatter(lons[iwant], lats[iwant], c = values[iwant], vmin=150, vmax=550, cmap = 'jet', s = 1)

# %%
lats[iwant].max()
# Out:
# 89.0

# %%
for filename in filenames:
    date = filename[21:30]
    year = date[:4]
    month = date[-4:-2]
    day = date[-2:]
    print(year, month, day)
    
    try:
        f = Dataset(dir_ozone + filename)

        lons = f.variables['lon'][:].data
        lons[lons > 180] -= 360
        lats = f.variables['lat'][:].data
        lons, lats = np.meshgrid(lons, lats)
        values = f.variables['ColumnAmountO3'][:].data
        
    except:
        print('Error on reading file of ', year, month, day)
#     break
# Out:
# ([<matplotlib.axis.XTick at 0x159df7310>,
#   <matplotlib.axis.XTick at 0x159df72e0>,
#   <matplotlib.axis.XTick at 0x159d9cca0>,
#   <matplotlib.axis.XTick at 0x159e58280>,
#   <matplotlib.axis.XTick at 0x159e58790>,
#   <matplotlib.axis.XTick at 0x159e58ca0>,
#   <matplotlib.axis.XTick at 0x159e5d1f0>],
#  [Text(-180, 0, '-180'),
#   Text(-120, 0, '-120'),
#   Text(-60, 0, '-60'),
#   Text(0, 0, '0'),
#   Text(60, 0, '60'),
#   Text(120, 0, '120'),
#   Text(180, 0, '180')])

# %%
a.variables['ColumnAmountO3'][:]
# Out:
# masked_array(
#   data=[[--, --, --, ..., --, --, --],
#         [--, --, --, ..., --, --, --],
#         [--, --, --, ..., --, --, --],
#         ...,
#         [309.1500244140625, 309.1500244140625, 309.1500244140625, ...,
#          309.1000061035156, 309.1000061035156, 309.1000061035156],
#         [299.25, 299.25, 299.25, ..., 299.25, 299.25, 299.25],
#         [298.20001220703125, 298.20001220703125, 298.20001220703125, ...,
#          298.20001220703125, 298.20001220703125, 298.20001220703125]],
#   mask=[[ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         ...,
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False]],
#   fill_value=-1.2676506e+30,
#   dtype=float32)

# %%
a.variables['lat'].shape
# Out:
# (181,)

# %%
values
# Out:
# array([[-1.2676506e+30, -1.2676506e+30, -1.2676506e+30, ...,
#         -1.2676506e+30, -1.2676506e+30, -1.2676506e+30],
#        [-1.2676506e+30, -1.2676506e+30, -1.2676506e+30, ...,
#         -1.2676506e+30, -1.2676506e+30, -1.2676506e+30],
#        [-1.2676506e+30, -1.2676506e+30, -1.2676506e+30, ...,
#         -1.2676506e+30, -1.2676506e+30, -1.2676506e+30],
#        ...,
#        [ 3.0915002e+02,  3.0915002e+02,  3.0915002e+02, ...,
#          3.0910001e+02,  3.0910001e+02,  3.0910001e+02],
#        [ 2.9925000e+02,  2.9925000e+02,  2.9925000e+02, ...,
#          2.9925000e+02,  2.9925000e+02,  2.9925000e+02],
#        [ 2.9820001e+02,  2.9820001e+02,  2.9820001e+02, ...,
#          2.9820001e+02,  2.9820001e+02,  2.9820001e+02]], dtype=float32)

# %%
values = (a.variables['ColumnAmountO3'][:].data)

# %%
plt.hist(np.nan_to_num(values))
# Out:
# (array([[ 55.,   0.,   0., ...,   0.,   0., 126.],
#         [ 53.,   0.,   0., ...,   0.,   0., 128.],
#         [ 56.,   0.,   0., ...,   0.,   0., 125.],
#         ...,
#         [ 59.,   0.,   0., ...,   0.,   0., 122.],
#         [ 60.,   0.,   0., ...,   0.,   0., 121.],
#         [ 59.,   0.,   0., ...,   0.,   0., 122.]]),
#  array([-1.2676506e+30, -1.1408855e+30, -1.0141205e+30, -8.8735541e+29,
#         -7.6059039e+29, -6.3382530e+29, -5.0706025e+29, -3.8029520e+29,
#         -2.5353012e+29, -1.2676506e+29,  4.8500000e+02], dtype=float32),
#  <a list of 360 BarContainer objects>)
